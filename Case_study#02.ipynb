# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
data=pd.read_csv('D:\Sibina\ICT academy\Case Studies\Case Study#02\StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Q1.Find out how many males and females participated in the test

# %%
data1=data.groupby("gender").describe()

# %%
data1
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.590734  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.545643  ...  76.0  100.0         482.0  63.446058
#
#
#               std   min   25%   50%   75%    max
# gender
# female  14.844842  10.0  64.0  74.0  82.0  100.0
# male    14.227225  15.0  53.0  64.0  74.0  100.0
#
# [2 rows x 24 columns]

# %% [markdown]
# Number of Females is 518 and Number of Males 482

# %% [markdown]
# # Q2.What do you think about the students' parental level of education?

# %%
data2=data.groupby("parental level of education").describe()

# %%
data2
# Out:
#                             math score                                     \
#                                  count       mean        std   min    25%
# parental level of education
# associate's degree               222.0  67.977477  15.108190  26.0  57.00
# bachelor's degree                118.0  69.288136  15.164117  29.0  61.00
# high school                      196.0  61.821429  15.160466   8.0  53.75
# master's degree                   59.0  70.254237  14.843544  40.0  57.00
# some college                     226.0  67.128319  14.871790  11.0  59.00
# some high school                 179.0  63.134078  16.602894   0.0  53.00
#
#                                                reading score             ...  \
#                               50%   75%    max         count       mean  ...
# parental level of education                                              ...
# associate's degree           67.0  80.0  100.0         222.0  71.018018  ...
# ...

# %% [markdown]
# Majority of Parents are with some college eduaction(who started college but didn’t finish ) and least are with master's degree

# %% [markdown]
# # Q3.Who scores the most on average for math, reading and writing based on

# %% [markdown]
# # Q3.1.Gender

# %%
data1
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.590734  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.545643  ...  76.0  100.0         482.0  63.446058
#
#
#               std   min   25%   50%   75%    max
# gender
# female  14.844842  10.0  64.0  74.0  82.0  100.0
# male    14.227225  15.0  53.0  64.0  74.0  100.0
#
# [2 rows x 24 columns]

# %% [markdown]
# *Highsest average for math,reading & writing are as follows
# *math=Male=68.82
# *reading score=Female=72.59
# *writing score=Female=72.46
# So altogether, Females scored more

# %% [markdown]
# # Q3.2.Test preparation course

# %%
data3=data.groupby("test preparation course").describe()

# %%
data3
# Out:
#                         math score                                         \
#                              count      mean        std   min   25%   50%
# test preparation course
# completed                    358.0  69.96648  14.521847  23.0  61.0  70.0
# none                         642.0  63.78972  15.705689   0.0  54.0  64.0
#
#                                      reading score             ...        \
#                           75%    max         count       mean  ...   75%
# test preparation course                                        ...
# completed                79.0  100.0         358.0  74.175978  ...  84.0
# none                     74.0  100.0         642.0  66.417445  ...  76.0
#
#                                writing score                              \
#                            max         count       mean        std   min
# test preparation course
# completed                100.0         358.0  74.684358  13.236412  36.0
# ...

# %% [markdown]
# *Highsest average for math,reading & writing are as follows
# *math=Completed=69.96
# *reading score=completed=74.17
# *writing score=completed=74.68
#  those who completed the test preparation course scored more

# %% [markdown]
# # Q4.What do you think about the scoring variation for math, reading and writing based on

# %% [markdown]
# # Q4.1.Gender

# %% [markdown]
# *For math, Males scored more and for Reading & Writing Males Scored More

# %% [markdown]
# # Q4.2. Test Preparation course

# %% [markdown]
# *for all three sections math,reading and writing those who completed the test preparation course scored more than those didn't completed the course

# %% [markdown]
# # Q5.The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %% [markdown]
# *There are 1000 students, so top 25% students are first 250 students who scored top in maths

# %%
data.sort_values(by="math score",ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# *To Display First Students only

# %%
data.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 245  female        group B                 high school  free/reduced
# 246  female        group C          associate's degree  free/reduced
# 247  female        group C            some high school  free/reduced
# 248  female        group C                some college  free/reduced
# 249  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...
